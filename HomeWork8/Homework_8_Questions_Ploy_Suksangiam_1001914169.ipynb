# %% [markdown]
# # **Week 12. Homework 8. Pandas**
#
# ##Ploy Suksangiam
# ##1001914169

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 1. Load the dataset into a pandas DataFrame and display the first few rows.

# %%
import pandas as pd

startup_df=pd.read_csv("Startups (2).csv")

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 2. Find the number of rows and columns in the dataset.

# %%
startup_df.shape
# Out:
# (50, 5)

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 3. Check for missing values in each column and handle them appropriately.

# %%
missing_values=startup_df.isnull()




print(missing_values)
# Out:
#     R&D Spend  Administration  Marketing Spend  State  Profit
# 0       False           False            False  False   False
# 1       False           False            False  False   False
# 2       False           False            False  False   False
# 3       False           False            False  False   False
# 4       False           False            False  False   False
# 5       False           False            False  False   False
# 6       False           False            False  False   False
# 7       False           False            False  False   False
# 8       False           False            False  False   False
# 9       False           False            False  False   False
# 10      False           False            False  False   False
# 11      False           False            False  False   False
# 12      False           False            False  False   False
# 13      False           False            False  False   False
# 14      False           False            False  False   False
# 15      False           False            False  False   False
# 16      False           False            False  False   False
# 17      False           False            False  False   False
# 18      False           False            False  False   False
# 19      False           False            False  False   False
# 20      False           False            False  False   False
# 21      False           False            False  False   False
# 22      False           False            False  False   False
# 23      False           False            False  False   False
# 24      False           False            False  False   False
# 25      False           False            False  False   False
# 26      False           False            False  False   False
# 27      False           False            False  False   False
# 28      False           False            False  False   False
# 29      False           False            False  False   False
# 30      False           False            False  False   False
# 31      False           False            False  False   False
# 32      False           False            False  False   False
# 33      False           False            False  False   False
# 34      False           False            False  False   False
# 35      False           False            False  False   False
# 36      False           False            False  False   False
# 37      False           False            False  False   False
# 38      False           False            False  False   False
# 39      False           False            False  False   False
# 40      False           False            False  False   False
# 41      False           False            False  False   False
# 42      False           False            False  False   False
# 43      False           False            False  False   False
# 44      False           False            False  False   False
# 45      False           False            False  False   False
# 46      False           False            False  False   False
# 47      False           False            False  False   False
# 48      False           False            False  False   False
# 49      False           False            False  False   False

# %%
missing_values.sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 4. Calculate the mean, median, and standard deviation of the 'R&D_Spend' column.

# %%
startup_df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
startup_df["R&D Spend"].describe()
# Out:
# count        50.000000
# mean      73721.615600
# std       45902.256482
# min           0.000000
# 25%       39936.370000
# 50%       73051.080000
# 75%      101602.800000
# max      165349.200000
# Name: R&D Spend, dtype: float64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 5. Filter and create a new DataFrame containing companies located in a **California**.

# %%
filter_df=startup_df[(startup_df["State"]=="California")]

filter_df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 1   162597.70       151377.59        443898.53  California  191792.06
# 6   134615.46       147198.87        127716.82  California  156122.51
# 9   123334.88       108679.17        304981.62  California  149759.96
# 11  100671.96        91790.61        249744.55  California  144259.40
# 13   91992.39       135495.07        252664.93  California  134307.35
# 16   78013.11       121597.55        264346.06  California  126992.93
# 20   76253.86       113867.30        298664.47  California  118474.03
# 25   64664.71       139553.16        137962.62  California  107404.34
# 32   63408.86       129219.61         46085.25  California   97427.84
# 34   46426.07       157693.92        210797.67  California   96712.80
# 37   44069.95        51283.14        197029.42  California   89949.14
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 42   23640.93        96189.63        148001.11  California   71498.49
# 44   22177.74       154806.14         28334.72  California   65200.33
# 47       0.00       135426.92             0.00  California   42559.73
# 49       0.00       116983.80         45173.06  California   14681.40

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 6. Sort the dataset by 'Profit' in descending order.

# %%
startup_df.sort_values("Profit",ascending=False)



startup_df["Profit"]
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 7. Group the data by 'State' and calculate the total 'Profit' for each state.

# %%
len(startup_df["State"])
# Out:
# 50

# %%
(startup_df["State"]).unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
the_total=startup_df.groupby("State")["Profit"].sum()

the_total
# Out:
# State
# California    1766387.98
# Florida       1900384.39
# New York      1933859.59
# Name: Profit, dtype: float64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 8. Create a bar chart to visualize the total 'Profit' by 'State.'

# %%
import seaborn as sns
from seaborn.widgets import plt
from matplotlib.pyplot import plot

# %%
#adding a column "sum_state" into the dataframe

total_profit=startup_df["the_total"]=startup_df.groupby("State")["Profit"].sum()

# %%
startup_df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit',
#        'the_total'],
#       dtype='object')

# %%
total_profit.plot(kind="bar",color="green")

plt.title("The Total profit by State")
plt.show()

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 9. Calculate the correlation between 'R&D_Spend' and 'Profit.'

# %%
correlation=startup_df["R&D Spend"].corr(startup_df["Profit"])
print(correlation)


#correlation_profit_spend=correlation.loc['R&D Spend','Profit']
#print(correlation_profit_spend)
# Out:
# 0.9729004656594832

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 10. Create a new column 'Total_Spend' that represents the sum of 'R&D_Spend,' 'Administration,' and 'Marketing_Spend' for each company.

# %%
startup_df["Total_Spend"]=startup_df[["R&D Spend","Administration","Marketing Spend"]].sum(axis=1)

# %%
startup_df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit',
#        'the_total', 'Total_Spend'],
#       dtype='object')

# %% [markdown]
# 11. Calculate the average **R&D_Spend**, **Administration**, and **Marketing_Spend** for companies located in each **State**

# %%
startup_df.groupby("State")[["R&D Spend","Administration","Marketing Spend"]].mean()
# Out:
#                R&D Spend  Administration  Marketing Spend
# State
# California  64657.674118   120746.507059    182540.929412
# Florida     80724.016250   121768.897500    247323.551250
# New York    76195.062353   121543.470588    205346.015882

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 12. Create a histogram to visualize the distribution of 'Profit.'

# %%
startup_df["Profit"].plot(kind="hist",bins=10, color='skyblue', edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 13. Filter the dataset to include only companies with 'R&D_Spend' greater than a 12000.

# %%
filter_companies=startup_df[startup_df["R&D Spend"]>12000]
filter_companies
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
#
#     the_total  Total_Spend  Profit_Margin
# 0         NaN    774031.10       0.248390
# 1         NaN    757873.82       0.253066
# 2         NaN    662521.60       0.288369
# 3         NaN    646243.88       0.283023
# 4         NaN    599667.53       0.277133
# 5         NaN    594552.97       0.264049
# 6         NaN    409531.15       0.381223
# 7         NaN    599704.87       0.259715
# 8         NaN    580874.76       0.262039
# 9         NaN    536995.67       0.278885
# 10        NaN    441668.14       0.330841
# 11        NaN    442207.12       0.326226
# 12        NaN    471023.57       0.300591
# 13        NaN    480152.39       0.279718
# 14        NaN    533003.58       0.248784
# 15        NaN    498916.68       0.260398
# 16        NaN    463956.72       0.273717
# 17        NaN    522309.05       0.240031
# 18        NaN    500844.52       0.248115
# 19        NaN    239933.81       0.511711
# 20        NaN    488785.63       0.242384
# 21        NaN    531900.19       0.209274
# 22        NaN    500096.57       0.220662
# 23        NaN    478052.29       0.227452
# 24        NaN    316900.16       0.342543
# 25        NaN    342180.49       0.313882
# 26        NaN    353514.92       0.299092
# 27        NaN    553155.96       0.189835
# 28        NaN    366845.28       0.281542
# 29        NaN    325775.92       0.310043
# 30        NaN    268767.00       0.371837
# 31        NaN    302056.53       0.322733
# 32        NaN    238713.72       0.408137
# 33        NaN    373186.25       0.259331
# 34        NaN    414917.66       0.233089
# 35        NaN    336579.10       0.286647
# 36        NaN    356846.79       0.254194
# 37        NaN    292382.51       0.307642
# 38        NaN    271442.62       0.299249
# 39        NaN    296539.90       0.273170
# 40        NaN    320096.05       0.244426
# 41        NaN    277074.40       0.280787
# 42        NaN    267831.67       0.266953
# 43        NaN    178422.20       0.390977
# 44        NaN    205318.60       0.317557

# %%
#filter_companies=startup_df["R&D Spend"]>12000
#print(filter_companies)
#only print out booleans

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 14. Calculate the total 'Profit' for companies with 'Marketing_Spend' above a certain threshold.

# %% [markdown]
# 15. Replace any missing values in the 'Marketing_Spend' column with the mean spending of the dataset.

# %%
startup_df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit',
#        'the_total', 'Total_Spend'],
#       dtype='object')

# %%
mean_spending=startup_df['Marketing Spend'].mean()

startup_df['Marketing Spend']=startup_df['Marketing Spend'].fillna(mean_spending)
startup_df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40
#
#     the_total  Total_Spend
# 0         NaN    774031.10
# 1         NaN    757873.82
# 2         NaN    662521.60
# 3         NaN    646243.88
# 4         NaN    599667.53
# 5         NaN    594552.97
# 6         NaN    409531.15
# 7         NaN    599704.87
# 8         NaN    580874.76
# 9         NaN    536995.67
# 10        NaN    441668.14
# 11        NaN    442207.12
# 12        NaN    471023.57
# 13        NaN    480152.39
# 14        NaN    533003.58
# 15        NaN    498916.68
# 16        NaN    463956.72
# 17        NaN    522309.05
# 18        NaN    500844.52
# 19        NaN    239933.81
# 20        NaN    488785.63
# 21        NaN    531900.19
# 22        NaN    500096.57
# 23        NaN    478052.29
# 24        NaN    316900.16
# 25        NaN    342180.49
# 26        NaN    353514.92
# 27        NaN    553155.96
# 28        NaN    366845.28
# 29        NaN    325775.92
# 30        NaN    268767.00
# 31        NaN    302056.53
# 32        NaN    238713.72
# 33        NaN    373186.25
# 34        NaN    414917.66
# 35        NaN    336579.10
# 36        NaN    356846.79
# 37        NaN    292382.51
# 38        NaN    271442.62
# 39        NaN    296539.90
# 40        NaN    320096.05
# 41        NaN    277074.40
# 42        NaN    267831.67
# 43        NaN    178422.20
# 44        NaN    205318.60
# 45        NaN    127057.20
# 46        NaN    414246.13
# 47        NaN    135426.92
# 48        NaN     52285.20
# 49        NaN    162156.86

# %%
startup_df.isnull().sum()
# Out:
# R&D Spend           0
# Administration      0
# Marketing Spend     0
# State               0
# Profit              0
# the_total          50
# Total_Spend         0
# dtype: int64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 16. Create a new column 'Profit_Margin' that represents the profit margin for each company (Profit / Total_Spend).

# %%
startup_df["Profit_Margin"]=startup_df["Profit"]/startup_df["Total_Spend"]

# %%
startup_df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit',
#        'the_total', 'Total_Spend', 'Profit_Margin'],
#       dtype='object')

# %%
startup_df["Profit_Margin"]
# Out:
# 0     0.248390
# 1     0.253066
# 2     0.288369
# 3     0.283023
# 4     0.277133
# 5     0.264049
# 6     0.381223
# 7     0.259715
# 8     0.262039
# 9     0.278885
# 10    0.330841
# 11    0.326226
# 12    0.300591
# 13    0.279718
# 14    0.248784
# 15    0.260398
# 16    0.273717
# 17    0.240031
# 18    0.248115
# 19    0.511711
# 20    0.242384
# 21    0.209274
# 22    0.220662
# 23    0.227452
# 24    0.342543
# 25    0.313882
# 26    0.299092
# 27    0.189835
# 28    0.281542
# 29    0.310043
# 30    0.371837
# 31    0.322733
# 32    0.408137
# 33    0.259331
# 34    0.233089
# 35    0.286647
# 36    0.254194
# 37    0.307642
# 38    0.299249
# 39    0.273170
# 40    0.244426
# 41    0.280787
# 42    0.266953
# 43    0.390977
# 44    0.317557
# 45    0.510999
# 46    0.119472
# 47    0.314263
# 48    0.682285
# 49    0.090538
# Name: Profit_Margin, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 17. Sort the dataset by 'Profit_Margin' in descending order.

# %%
startup_df["Profit_Margin"].sort_values(ascending=False)
# Out:
# 48    0.682285
# 19    0.511711
# 45    0.510999
# 32    0.408137
# 43    0.390977
# 6     0.381223
# 30    0.371837
# 24    0.342543
# 10    0.330841
# 11    0.326226
# 31    0.322733
# 44    0.317557
# 47    0.314263
# 25    0.313882
# 29    0.310043
# 37    0.307642
# 12    0.300591
# 38    0.299249
# 26    0.299092
# 2     0.288369
# 35    0.286647
# 3     0.283023
# 28    0.281542
# 41    0.280787
# 13    0.279718
# 9     0.278885
# 4     0.277133
# 16    0.273717
# 39    0.273170
# 42    0.266953
# 5     0.264049
# 8     0.262039
# 15    0.260398
# 7     0.259715
# 33    0.259331
# 36    0.254194
# 1     0.253066
# 14    0.248784
# 0     0.248390
# 18    0.248115
# 40    0.244426
# 20    0.242384
# 17    0.240031
# 34    0.233089
# 23    0.227452
# 22    0.220662
# 21    0.209274
# 27    0.189835
# 46    0.119472
# 49    0.090538
# Name: Profit_Margin, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 18. Calculate the average profit margin for companies in each 'State' and create a bar chart to display it.

# %%
startup_df.groupby("State")["Profit_Margin"].mean()
# Out:
# State
# California    0.282640
# Florida       0.266745
# New York      0.330249
# Name: Profit_Margin, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(startup_df["State"], startup_df["Profit_Margin"])
plt.xlabel("State")
plt.ylabel("Profit Margin")
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 19. Find the maximum 'R&D_Spend' in each **State**.

# %%
startup_df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit',
#        'the_total', 'Total_Spend', 'Profit_Margin'],
#       dtype='object')

# %%
startup_df.groupby("State")["R&D Spend"].max()
# Out:
# State
# California    162597.70
# Florida       153441.51
# New York      165349.20
# Name: R&D Spend, dtype: float64
