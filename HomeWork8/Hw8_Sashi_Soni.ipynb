# %% [markdown]
# # **Week 12. Homework 8. Pandas**

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Load the dataset into a pandas DataFrame and display the first few rows.

# %%
data=pd.read_csv('Startups.csv')
data.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 2. Find the number of rows and columns in the dataset.

# %%
data.shape
print(f"The number of rows and columns: {data.shape}")
# Out:
# The number of rows and columns: (50, 5)

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 3. Check for missing values in each column and handle them appropriately.

# %%
print(f"Missing values in each are:")
print(data.isnull().sum())
# Out:
# Missing values in each are:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 4. Calculate the mean, median, and standard deviation of the 'R&D_Spend' column.

# %%
print(f"Mean of R&D_Spend: {data['R&D Spend'].mean()}")
print(f"Median of R&D_Spend: {data['R&D Spend'].median()}")
print(f"Standard Deviation of R&D_Spend: {data['R&D Spend'].std()}")
# Out:
# Mean of R&D_Spend: 73721.6156
# Median of R&D_Spend: 73051.08
# Standard Deviation of R&D_Spend: 45902.25648230753

# %%
data['R&D Spend'].describe() # to check with a simple code
# Out:
# count        50.000000
# mean      73721.615600
# std       45902.256482
# min           0.000000
# 25%       39936.370000
# 50%       73051.080000
# 75%      101602.800000
# max      165349.200000
# Name: R&D Spend, dtype: float64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 5. Filter and create a new DataFrame containing companies located in a **California**.

# %%
filtered_data=data[data.State=="California"]
print(f"The new DataFrame containing companies located at California are:")
print(filtered_data)
# Out:
# The new DataFrame containing companies located at California are:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 1   162597.70       151377.59        443898.53  California  191792.06
# 6   134615.46       147198.87        127716.82  California  156122.51
# 9   123334.88       108679.17        304981.62  California  149759.96
# 11  100671.96        91790.61        249744.55  California  144259.40
# 13   91992.39       135495.07        252664.93  California  134307.35
# 16   78013.11       121597.55        264346.06  California  126992.93
# 20   76253.86       113867.30        298664.47  California  118474.03
# 25   64664.71       139553.16        137962.62  California  107404.34
# 32   63408.86       129219.61         46085.25  California   97427.84
# 34   46426.07       157693.92        210797.67  California   96712.80
# 37   44069.95        51283.14        197029.42  California   89949.14
# ...

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 6. Sort the dataset by 'Profit' in descending order.

# %%
data_sorted=data.sort_values(by="Profit", ascending=False)
data_sorted
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 7. Group the data by 'State' and calculate the total 'Profit' for each state.

# %%
agg_data=data.groupby('State').agg({'Profit':'sum'}).reset_index()
agg_data
# Out:
#         State      Profit
# 0  California  1766387.98
# 1     Florida  1900384.39
# 2    New York  1933859.59

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 8. Create a bar chart to visualize the total 'Profit' by 'State.'

# %%
sns.barplot(data=agg_data, x='State', y='Profit',color="red")
plt.title("Total Profit by State")
plt.xlabel("State")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# ---
#
#
# ---

# %%
agg_data.describe()  #just random thing to see agg_data
# Out:
#              Profit
# count  3.000000e+00
# mean   1.866877e+06
# std    8.862126e+04
# min    1.766388e+06
# 25%    1.833386e+06
# 50%    1.900384e+06
# 75%    1.917122e+06
# max    1.933860e+06

# %% [markdown]
# 9. Calculate the correlation between 'R&D_Spend' and 'Profit.'

# %%
corr=data['R&D Spend'].corr(data['Profit'])
print(corr)
# Out:
# 0.9729004656594832

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 10. Create a new column 'Total_Spend' that represents the sum of 'R&D_Spend,' 'Administration,' and 'Marketing_Spend' for each company.

# %%
data['Total_Spend'] = data['R&D Spend'] + data['Administration'] + data['Marketing Spend']
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# 11. Calculate the average **R&D_Spend**, **Administration**, and **Marketing_Spend** for companies located in each **State**

# %%
avg_data=data.groupby('State')[['R&D Spend', 'Administration', 'Marketing Spend']].mean().reset_index()
avg_data
# Out:
#         State     R&D Spend  Administration  Marketing Spend
# 0  California  64657.674118   120746.507059    182540.929412
# 1     Florida  80724.016250   121768.897500    247323.551250
# 2    New York  76195.062353   121543.470588    205346.015882

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 12. Create a histogram to visualize the distribution of 'Profit.'

# %%
sns.histplot(data["Profit"],kde=True)
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.title("Histogram Plot")
plt.show()

# %%
# or

data["Profit"].plot(kind='hist')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 13. Filter the dataset to include only companies with 'R&D_Spend' greater than a 12000.

# %%
filtered_df = data[data['R&D Spend'] > 12000]
filtered_df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 14. Calculate the total 'Profit' for companies with 'Marketing_Spend' above a certain threshold.

# %%
above_certain_threshold=data[data['Marketing Spend'] > 180000]
total_profit= above_certain_threshold['Profit'].sum()
print(f"The total profit for companies with Marketing Spend above $180,000 threshold: {total_profit}")
# Out:
# The total profit for companies with Marketing Spend above $180,000 threshold: 3899563.7399999998

# %% [markdown]
# 15. Replace any missing values in the 'Marketing_Spend' column with the mean spending of the dataset.

# %%
# No missing values as we checked in question number 3 but also, let's run the code and see again
data["Marketing Spend"].fillna(data["Marketing Spend"].mean(), inplace=True)
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 16. Create a new column 'Profit_Margin' that represents the profit margin for each company (Profit / Total_Spend).

# %%
data["Profit_Margin"]=data['Profit']/data['Total_Spend']
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 17. Sort the dataset by 'Profit_Margin' in descending order.

# %%
data_sorted=data.sort_values(by='Profit_Margin', ascending=False)
data_sorted
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 48     542.05        51743.15             0.00    New York   35673.41
# 19   86419.70       153514.11             0.00    New York  122776.86
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 32   63408.86       129219.61         46085.25  California   97427.84
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 6   134615.46       147198.87        127716.82  California  156122.51
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 44   22177.74       154806.14         28334.72  California   65200.33
# ...

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 18. Calculate the average profit margin for companies in each 'State' and create a bar chart to display it.

# %%
avg_pro_margin=data.groupby('State')['Profit_Margin'].mean().reset_index()

plt.figure(figsize=(12,8))
plt.bar(avg_pro_margin['State'], avg_pro_margin['Profit_Margin'], color='darkgreen')
plt.xlabel('State')
plt.ylabel('Average Profit Margin')
plt.title('Average Profit Margin by State')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 19. Find the maximum 'R&D_Spend' in each **State**.

# %%
max=data.groupby('State')['R&D Spend'].max().reset_index()
print(f"The maximum R&D Spend of each State:")
print(max)
# Out:
# The maximum R&D Spend of each State:
#         State  R&D Spend
# 0  California  162597.70
# 1     Florida  153441.51
# 2    New York  165349.20

# %% [markdown]
# #      **THANK YOU**
