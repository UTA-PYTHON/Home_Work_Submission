# %% [markdown]
# # **Week 13. Data Visualization Homework**

# %% [markdown]
# ### Use the `housing_california.csv` dataset to answer the questions.

# %% [markdown]
# ### **Question 1**

# %% [markdown]
# #### Histogram of Median Housing Prices:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv("housing_california.csv")


data["median_house_value"].hist(bins=50)
plt.xlabel("Number of houses")
plt.ylabel('Median price oh houses')


plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 2**

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# #### Scatter Plot of Population vs. Median House Value:

# %%
plt.scatter(data["population"],data["median_house_value"], color = "purple")
plt.title("Scatter Plot of Population vs. Median House Value")
plt.xlabel("Population")
plt.ylabel("Median House Value")
plt.show()

# %% [markdown]
# ---
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 3**

# %% [markdown]
# #### Box Plot of Median Income:

# %%
sns.boxplot(data["median_house_value"])
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 4**

# %% [markdown]
# #### Pair Plot for Select Columns:

# %%
selected_columns = ["total_rooms", "total_bedrooms", "housing_median_age"]
selected_data = data[selected_columns]
selected_data
# Out:
#        total_rooms  total_bedrooms  housing_median_age
# 0            880.0           129.0                41.0
# 1           7099.0          1106.0                21.0
# 2           1467.0           190.0                52.0
# 3           1274.0           235.0                52.0
# 4           1627.0           280.0                52.0
# ...            ...             ...                 ...
# 20635       1665.0           374.0                25.0
# 20636        697.0           150.0                18.0
# 20637       2254.0           485.0                17.0
# 20638       1860.0           409.0                18.0
# 20639       2785.0           616.0                16.0
#
# [20640 rows x 3 columns]

# %% [markdown]
# ---
#
#
# ---
#
#
#
# ---

# %%
sns.pairplot(selected_data)
plt.show()

# %% [markdown]
# ### **Question 5**

# %% [markdown]
# #### Bar Plot of Ocean Proximity Counts:

# %%
ocean_prox_counts = data["ocean_proximity"].value_counts()
ocean_prox_counts.plot(kind='bar')
plt.xlabel("Ocean Proximity Values")
plt.ylabel("Count of Ocean Proximity values")
plt.show()

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 6**

# %% [markdown]
# #### Correlation Heatmap:

# %%
hmpplt = sns.heatmap(data.corr(),annot=True)
plt.title("Corelation Heatmap")
plt.show()
# Out:
# <ipython-input-53-37a2c7657402>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hmpplt = sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 7**

# %% [markdown]
# #### Density Plot of Housing Median Age:

# %%
data["housing_median_age"].plot(kind='density')
plt.title("density plot")
plt.xlabel("Housing Median Age")
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 8**

# %% [markdown]
# #### Stacked Area Plot of Total Rooms and Bedrooms:

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
selected_colums = ["total_rooms","total_bedrooms"]
room_columns = data[selected_columns]

data.plot(kind='area', stacked=True, y=['total_rooms', 'total_bedrooms'])

plt.title('Stacked Area Plot Example')
plt.xlabel('Time')
plt.ylabel('Values')

plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 9**

# %% [markdown]
# #### Hexbin Plot of Latitude and Longitude:

# %%
plt.hexbin(data["latitude"],data["longitude"], gridsize = 10, cmap ="Blues")
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.title('Hexbin Plot')
# Out:
# Text(0.5, 1.0, 'Hexbin Plot')

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 10**

# %% [markdown]
# #### Facet Grid of Scatter Plots:

# %%
g = sns.FacetGrid(data,col =  "median_income", col_wrap = 5, height = 2)
g = g.map(plt.scatter, "x_col", "y_col")
plt.figure(figsize=(100, 80))

g.add_legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-fbb0a7426454> in <cell line: 1>()
# ----> 1 g = sns.FacetGrid(data,col =  "median_income", col_wrap = 5, height = 2)
#       2 g = g.map(plt.scatter, "x_col", "y_col")
#       3 plt.figure(figsize=(100, 80))
#       4
#       5 g.add_legend()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     480                 subplot_kws["sharey"] = axes[0]
#     481             for i in range(1, n_axes):
# --> 482                 axes[i] = fig.add_subplot(nrow, ncol, i + 1, **subplot_kws)
#     483
#     484             axes_dict = dict(zip(col_names, axes))
#
# ...
